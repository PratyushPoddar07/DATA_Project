# %%
# Dtale

# %%
# !pip install dtale

# %%
# !pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import dtale

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Pratyush:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2025-04-08 23:52:25,083 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,104 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,106 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,109 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,112 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,117 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,120 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,122 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2025-04-08 23:52:25,124 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...
