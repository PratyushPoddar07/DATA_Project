# %% [markdown]
# ## Airbnb Stock price prediction
#
# - The goal of this project is to predict Airbnb's stock closing prices using historical stock market data. By leveraging machine learning models, we aim to develop an effective forecasting system to assist investors and analysts in decision-making.
# ### 1. Data Loading and preprocessing
# - import Required Libraries

# %%
# libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set_theme(color_codes =True)

# %%
# load dataset
df = pd.read_csv(r"C:\Users\shuva\Downloads\archive (2)\ABNB.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-12-11  146.550003  151.500000  135.100006  139.250000  139.250000
# 1  2020-12-14  135.000000  135.300003  125.160004  130.000000  130.000000
# 2  2020-12-15  126.690002  127.599998  121.500000  124.800003  124.800003
# 3  2020-12-16  125.830002  142.000000  124.910004  137.990005  137.990005
# 4  2020-12-17  143.000000  152.449997  142.669998  147.050003  147.050003
#
#      Volume
# 0  26980800
# 1  16966100
# 2  10914400
# 3  20409600
# 4  15054700

# %% [markdown]
# ### Convert Date column to Date Time Format

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace = True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-11  146.550003  151.500000  135.100006  139.250000  139.250000
# 2020-12-14  135.000000  135.300003  125.160004  130.000000  130.000000
# 2020-12-15  126.690002  127.599998  121.500000  124.800003  124.800003
# 2020-12-16  125.830002  142.000000  124.910004  137.990005  137.990005
# 2020-12-17  143.000000  152.449997  142.669998  147.050003  147.050003
#
#               Volume
# Date
# 2020-12-11  26980800
# 2020-12-14  16966100
# 2020-12-15  10914400
# 2020-12-16  20409600
# 2020-12-17  15054700

# %% [markdown]
# ### 2. EDA (exploratory data analysis
# - visualizing stock price trends

# %%
plt.figure(figsize =(12,6))
plt.plot(df.index,df['Close'],label = 'Closing Price',color = 'b')
plt.xlabel('Date')
plt.ylabel('Stock Price (USD)')
plt.title('AirBnB Stock closing price over time')
plt.legend()
plt.xticks(rotation = 90)
# Out:
# (array([18628., 18718., 18809., 18901., 18993., 19083., 19174., 19266.]),
#  [Text(18628.0, 0, '2021-01'),
#   Text(18718.0, 0, '2021-04'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18901.0, 0, '2021-10'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19083.0, 0, '2022-04'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19266.0, 0, '2022-10')])

# %% [markdown]
# ### Feature Enginerring: Extracting Date Features

# %%
def create_features_datetime(df):
    df['Year'] = df.index.year
    df['Month'] = df.index.month
    df['DayOfWeek'] = df.index.dayofweek
    return df
df = create_features_datetime(df)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-11  146.550003  151.500000  135.100006  139.250000  139.250000
# 2020-12-14  135.000000  135.300003  125.160004  130.000000  130.000000
# 2020-12-15  126.690002  127.599998  121.500000  124.800003  124.800003
# 2020-12-16  125.830002  142.000000  124.910004  137.990005  137.990005
# 2020-12-17  143.000000  152.449997  142.669998  147.050003  147.050003
#
#               Volume  Year  Month  DayOfWeek
# Date
# 2020-12-11  26980800  2020     12          4
# 2020-12-14  16966100  2020     12          0
# 2020-12-15  10914400  2020     12          1
# 2020-12-16  20409600  2020     12          2
# 2020-12-17  15054700  2020     12          3

# %% [markdown]
# ### 3. ML model for Stock Price Prediction
# - Splitting Data into Train and Test sets

# %%
X = df.drop(['Close'],axis =1)
X.head(5)
# Out:
#                   Open        High         Low   Adj Close    Volume  Year  \
# Date
# 2020-12-11  146.550003  151.500000  135.100006  139.250000  26980800  2020
# 2020-12-14  135.000000  135.300003  125.160004  130.000000  16966100  2020
# 2020-12-15  126.690002  127.599998  121.500000  124.800003  10914400  2020
# 2020-12-16  125.830002  142.000000  124.910004  137.990005  20409600  2020
# 2020-12-17  143.000000  152.449997  142.669998  147.050003  15054700  2020
#
#             Month  DayOfWeek
# Date
# 2020-12-11     12          4
# 2020-12-14     12          0
# 2020-12-15     12          1
# 2020-12-16     12          2
# 2020-12-17     12          3

# %%
y =df.Close
y
# Out:
# Date
# 2020-12-11    139.250000
# 2020-12-14    130.000000
# 2020-12-15    124.800003
# 2020-12-16    137.990005
# 2020-12-17    147.050003
#                  ...
# 2022-09-26    103.230003
# 2022-09-27    106.370003
# 2022-09-28    110.690002
# 2022-09-29    106.660004
# 2022-09-30    105.040001
# Name: Close, Length: 454, dtype: float64

# %% [markdown]
# ## train-test-split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state =0)

# %% [markdown]
# #### Model I: Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtree = DecisionTreeRegressor(random_state =0)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dtree.predict(X_test)

# %%
import math
from sklearn import metrics

# %%
mae_dt= metrics.mean_absolute_error(y_test,y_pred)
mse_dt = metrics.mean_squared_error(y_test,y_pred)
r2_dt = metrics.r2_score(y_test,y_pred)
rmse_dt = math.sqrt(mse_dt)

# %%
print(f"Decision_Tree = MAE: {mae_dt:.4f}, MSE: {mse_dt:.4f}, R2: {r2_dt:.4f}, RMSE: {rmse_dt:.4f}")
# Out:
# Decision_Tree = MAE: 0.3470, MSE: 0.2695, R2: 0.9997, RMSE: 0.5191

# %% [markdown]
# ## 4. visualizing prediction using Decision Tree
# - Adding Prediction to the Dataset

# %%
df['Predicted_close'] = dtree.predict(X)

# %% [markdown]
# #### Plot Actual vs Predicted Stock Prices

# %%
plt.figure(figsize = (12,6))
plt.plot(df.index,df['Close'],label ='Actual Close Price',color = 'blue')
plt.plot(df.index,df['Predicted_close'],label = 'Predicted Close Price', color ='red',linestyle='dashed')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("AirBnB Stock Price Prediction using Decision tree")
plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# ### 5. Conclusion
# -  We successfully built a stock price prediction model using Decision Tree and Decision Tree Regressors.
# -  Visualization shows that our model effectively captures the trends in Airbnb’s stock prices.
# -  dataset link: https://www.kaggle.com/datasets/whenamancodes/airbnb-inc-stock-market-analysis?resource=downloades.

# %% [markdown]
# ## 6. visualization using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(random_state =0)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred_rf = rf.predict(X_test)

# %%
mae_rf= metrics.mean_absolute_error(y_test,y_pred_rf)
mse_rf = metrics.mean_squared_error(y_test,y_pred_rf)
r2_rf = metrics.r2_score(y_test,y_pred_rf)
rmse_rf = math.sqrt(mse_rf)
print(f"Random_forest = MAE: {mae_rf:.4f}, MSE: {mse_rf:.4f}, R2: {r2_rf:.4f}, RMSE: {rmse_rf:.4f}")
# Out:
# Random_forest = MAE: 0.2959, MSE: 0.2638, R2: 0.9997, RMSE: 0.5136

# %%
# visualize
df['Predicted_close_rf'] = rf.predict(X)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-11  146.550003  151.500000  135.100006  139.250000  139.250000
# 2020-12-14  135.000000  135.300003  125.160004  130.000000  130.000000
# 2020-12-15  126.690002  127.599998  121.500000  124.800003  124.800003
# 2020-12-16  125.830002  142.000000  124.910004  137.990005  137.990005
# 2020-12-17  143.000000  152.449997  142.669998  147.050003  147.050003
#
#               Volume  Year  Month  DayOfWeek  Predicted_close  \
# Date
# 2020-12-11  26980800  2020     12          4       139.250000
# 2020-12-14  16966100  2020     12          0       131.589996
# 2020-12-15  10914400  2020     12          1       124.800003
# 2020-12-16  20409600  2020     12          2       137.990005
# 2020-12-17  15054700  2020     12          3       147.050003
#
#             Predicted_close_rf
# Date
# 2020-12-11          139.164899
# 2020-12-14          130.719802
# 2020-12-15          125.152402
# 2020-12-16          136.527903
# 2020-12-17          146.952300

# %%
# plot
plt.figure(figsize = (12,6))
plt.plot(df.index,df['Close'],label ='Actual Close Price',color = 'blue')
plt.plot(df.index,df['Predicted_close'],label = 'Predicted Close Price', color ='red',linestyle='dashed')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("AirBnB Stock Price Prediction using Decision tree")
plt.xticks(rotation = 90)
plt.legend()
